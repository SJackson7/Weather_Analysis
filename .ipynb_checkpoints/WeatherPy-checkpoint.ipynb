# %% [markdown]
# ##  Weather Analysis

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as me
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
import datetime as dt

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_csv = 'output_data/city_weather_data.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# get precise date and time for data pull in appropriate time-stamp
today = dt.datetime.now().strftime('%Y/%m/%d at %H:%M:%S')

# %% [markdown]
# ### Generate Cities List

# %%
# lists for holding coordinates and city names
lat_lngs = []
cities = []

# set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# id nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # if the city is unique, add it to cities list
    if city not in cities:
        cities.append(city)

# print the city count to confirm if sufficient for study
print(len(cities))
# Out:
# 638

# %% [markdown]
# ### Perform API Calls

# %%
# set base url, units set to imperial, for open weather api call
url = 'https://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'
api_key = '&appid=' + weather_api_key


weather_data = []

# create beginning statement for city log.
print('Beginning City Data Retrieval')
print('-' * 40)

# set counters to limit api calls per minute
record_count = 1
set_count = 1

# loop through all the cities in the list, enumeration was far more efficient in creating loop
for i, city in enumerate(cities):
    query_url = f'{url}q={city}&units={units}{api_key}'
    # group in sets of 50 to log results, mod i by 50 to reset loop to new group
    if (i % 50 == 0 and i >= 50):
        # set time interval to not exceed API query call limit
        time.sleep(10)
        # increment counts
        set_count += 1
        record_count = 1
        
    print(f'Processing record {record_count} of set {set_count} | {city}.')
    record_count += 1
    weather_response = requests.get(query_url).json()
    #try to get weather data for each city
    try:
        name = weather_response['name']
        lat = weather_response['coord']['lat']
        lng = weather_response['coord']['lon']
        max_temp = weather_response['main']['temp_max']
        humidity = weather_response['main']['humidity']
        clouds = weather_response['clouds']['all']
        wind = weather_response['wind']['speed']
        country = weather_response['sys']['country']
        
        # append parsed data to weather_data
        weather_data.append({'City': name,
                             'Lat': lat,
                             'Lng': lng,
                             'Max Temp': max_temp,
                             'Humidity': humidity,
                             'Cloud Cover': clouds,
                             'Wind Speed': wind,
                             'Country': country
                            })

    except (KeyError, IndexError):
        print(f'Unable to complete record. Checking next city.')

print('Data Retrieval Complete.')
# Out:
# Beginning City Data Retrieval
# ----------------------------------------
# Processing record 1 of set 1 | punta arenas.
# Processing record 2 of set 1 | hermanus.
# Processing record 3 of set 1 | rajshahi.
# Processing record 4 of set 1 | yarmouth.
# Processing record 5 of set 1 | chuy.
# Processing record 6 of set 1 | cidreira.
# Processing record 7 of set 1 | godda.
# Processing record 8 of set 1 | popondetta.
# Processing record 9 of set 1 | arraial do cabo.
# Processing record 10 of set 1 | busselton.
# Processing record 11 of set 1 | nikolskoye.
# Processing record 12 of set 1 | tuktoyaktuk.
# Processing record 13 of set 1 | durant.
# Processing record 14 of set 1 | saskylakh.
# Processing record 15 of set 1 | ardesen.
# Processing record 16 of set 1 | rikitea.
# Processing record 17 of set 1 | mar del plata.
# Processing record 18 of set 1 | murgab.
# Processing record 19 of set 1 | qaanaaq.
# Processing record 20 of set 1 | kazalinsk.
# Unable to complete record. Checking next city.
# Processing record 21 of set 1 | maxixe.
# Processing record 22 of set 1 | ballymena.
# Processing record 23 of set 1 | gvarv.
# Processing record 24 of set 1 | lasa.
# Processing record 25 of set 1 | atuona.
# Processing record 26 of set 1 | kalutara.
# Processing record 27 of set 1 | tiksi.
# Processing record 28 of set 1 | williston.
# Processing record 29 of set 1 | constitucion.
# Processing record 30 of set 1 | ushuaia.
# Processing record 31 of set 1 | chokurdakh.
# Processing record 32 of set 1 | praia da vitoria.
# Processing record 33 of set 1 | makushino.
# Processing record 34 of set 1 | santa cruz.
# Processing record 35 of set 1 | talnakh.
# Processing record 36 of set 1 | coihaique.
# Processing record 37 of set 1 | mataura.
# Processing record 38 of set 1 | mattru.
# Processing record 39 of set 1 | acapulco.
# Processing record 40 of set 1 | vaini.
# Processing record 41 of set 1 | illoqqortoormiut.
# Unable to complete record. Checking next city.
# Processing record 42 of set 1 | vardo.
# Processing record 43 of set 1 | ponta do sol.
# Processing record 44 of set 1 | hithadhoo.
# Processing record 45 of set 1 | valparaiso.
# Processing record 46 of set 1 | aklavik.
# Processing record 47 of set 1 | pinawa.
# Processing record 48 of set 1 | uyuni.
# Processing record 49 of set 1 | neiafu.
# Processing record 50 of set 1 | mys shmidta.
# Unable to complete record. Checking next city.
# Processing record 1 of set 2 | hilo.
# Processing record 2 of set 2 | padang.
# Processing record 3 of set 2 | las vegas.
# Processing record 4 of set 2 | bredasdorp.
# Processing record 5 of set 2 | qingdao.
# Processing record 6 of set 2 | tuatapere.
# Processing record 7 of set 2 | bethel.
# Processing record 8 of set 2 | upata.
# Processing record 9 of set 2 | victoria.
# Processing record 10 of set 2 | cape town.
# Processing record 11 of set 2 | kapaa.
# Processing record 12 of set 2 | albany.
# Processing record 13 of set 2 | nizhneyansk.
# Unable to complete record. Checking next city.
# Processing record 14 of set 2 | karratha.
# Processing record 15 of set 2 | mount gambier.
# Processing record 16 of set 2 | castro.
# Processing record 17 of set 2 | bubaque.
# Processing record 18 of set 2 | utiroa.
# Unable to complete record. Checking next city.
# Processing record 19 of set 2 | avarua.
# Processing record 20 of set 2 | new glasgow.
# Processing record 21 of set 2 | east london.
# Processing record 22 of set 2 | orthez.
# Processing record 23 of set 2 | barrow.
# Processing record 24 of set 2 | shelburne.
# Processing record 25 of set 2 | barcelos.
# Processing record 26 of set 2 | belushya guba.
# Unable to complete record. Checking next city.
# Processing record 27 of set 2 | charlestown.
# Processing record 28 of set 2 | nuevo progreso.
# Processing record 29 of set 2 | ekimchan.
# Processing record 30 of set 2 | airai.
# Processing record 31 of set 2 | winneba.
# Processing record 32 of set 2 | butaritari.
# Processing record 33 of set 2 | zhanatas.
# Unable to complete record. Checking next city.
# Processing record 34 of set 2 | new norfolk.
# Processing record 35 of set 2 | ngukurr.
# Unable to complete record. Checking next city.
# Processing record 36 of set 2 | dikson.
# Processing record 37 of set 2 | thompson.
# Processing record 38 of set 2 | horsham.
# Processing record 39 of set 2 | saint george.
# Processing record 40 of set 2 | los llanos de aridane.
# Processing record 41 of set 2 | belokurikha.
# Processing record 42 of set 2 | tsihombe.
# Unable to complete record. Checking next city.
# Processing record 43 of set 2 | jiexiu.
# Processing record 44 of set 2 | kurilsk.
# Processing record 45 of set 2 | hihifo.
# Unable to complete record. Checking next city.
# Processing record 46 of set 2 | puerto ayora.
# Processing record 47 of set 2 | quang ngai.
# Processing record 48 of set 2 | tournon-sur-rhone.
# Processing record 49 of set 2 | burnie.
# Processing record 50 of set 2 | axim.
# Processing record 1 of set 3 | pevek.
# Processing record 2 of set 3 | husavik.
# Processing record 3 of set 3 | bengkulu.
# Processing record 4 of set 3 | yara.
# Processing record 5 of set 3 | port alfred.
# Processing record 6 of set 3 | hanyang.
# Processing record 7 of set 3 | sentyabrskiy.
# Unable to complete record. Checking next city.
# Processing record 8 of set 3 | markova.
# Processing record 9 of set 3 | yellowknife.
# Processing record 10 of set 3 | hofn.
# Processing record 11 of set 3 | attawapiskat.
# Unable to complete record. Checking next city.
# Processing record 12 of set 3 | saint-philippe.
# Processing record 13 of set 3 | ahuimanu.
# Processing record 14 of set 3 | sorland.
# Processing record 15 of set 3 | klaksvik.
# Processing record 16 of set 3 | smoky lake.
# Processing record 17 of set 3 | khatanga.
# Processing record 18 of set 3 | bluff.
# Processing record 19 of set 3 | bonthe.
# Processing record 20 of set 3 | pisco.
# Processing record 21 of set 3 | marcona.
# Unable to complete record. Checking next city.
# Processing record 22 of set 3 | saint-pierre.
# Processing record 23 of set 3 | caravelas.
# Processing record 24 of set 3 | culebra.
# Processing record 25 of set 3 | kiunga.
# Processing record 26 of set 3 | aktash.
# Processing record 27 of set 3 | kahului.
# Processing record 28 of set 3 | iqaluit.
# Processing record 29 of set 3 | san angelo.
# Processing record 30 of set 3 | hobart.
# Processing record 31 of set 3 | azimur.
# Unable to complete record. Checking next city.
# Processing record 32 of set 3 | lubango.
# Processing record 33 of set 3 | yumen.
# Processing record 34 of set 3 | henties bay.
# Processing record 35 of set 3 | grand gaube.
# Processing record 36 of set 3 | ballina.
# Processing record 37 of set 3 | yulara.
# Processing record 38 of set 3 | saleaula.
# Unable to complete record. Checking next city.
# Processing record 39 of set 3 | kampot.
# Processing record 40 of set 3 | tymovskoye.
# Processing record 41 of set 3 | paranapanema.
# Processing record 42 of set 3 | mullaitivu.
# Unable to complete record. Checking next city.
# Processing record 43 of set 3 | dingle.
# Processing record 44 of set 3 | nador.
# Processing record 45 of set 3 | tasiilaq.
# Processing record 46 of set 3 | arlit.
# Processing record 47 of set 3 | port said.
# Processing record 48 of set 3 | huayucachi.
# Processing record 49 of set 3 | faanui.
# Processing record 50 of set 3 | litovko.
# Processing record 1 of set 4 | geraldton.
# Processing record 2 of set 4 | cherskiy.
# Processing record 3 of set 4 | ilulissat.
# Processing record 4 of set 4 | nelson bay.
# Processing record 5 of set 4 | adrar.
# Processing record 6 of set 4 | jamestown.
# Processing record 7 of set 4 | alyangula.
# Processing record 8 of set 4 | vysokogornyy.
# Processing record 9 of set 4 | provideniya.
# Processing record 10 of set 4 | bardiyah.
# Processing record 11 of set 4 | quelimane.
# Processing record 12 of set 4 | port hardy.
# Processing record 13 of set 4 | bikapur.
# Processing record 14 of set 4 | kurumkan.
# Processing record 15 of set 4 | hambantota.
# Processing record 16 of set 4 | port keats.
# Processing record 17 of set 4 | baragua.
# Processing record 18 of set 4 | ancud.
# Processing record 19 of set 4 | nabire.
# Processing record 20 of set 4 | mayumba.
# Processing record 21 of set 4 | port hedland.
# Processing record 22 of set 4 | olafsvik.
# Processing record 23 of set 4 | lavrentiya.
# Processing record 24 of set 4 | ribeira grande.
# Processing record 25 of set 4 | makakilo city.
# Processing record 26 of set 4 | batangafo.
# Processing record 27 of set 4 | nome.
# Processing record 28 of set 4 | racale.
# Processing record 29 of set 4 | trogir.
# Processing record 30 of set 4 | sisimiut.
# Processing record 31 of set 4 | mount isa.
# Processing record 32 of set 4 | novellara.
# Processing record 33 of set 4 | pacific grove.
# Processing record 34 of set 4 | waingapu.
# Processing record 35 of set 4 | ulaanbaatar.
# Processing record 36 of set 4 | taolanaro.
# Unable to complete record. Checking next city.
# Processing record 37 of set 4 | shimoda.
# Processing record 38 of set 4 | port-gentil.
# Processing record 39 of set 4 | xichang.
# Processing record 40 of set 4 | ossora.
# Processing record 41 of set 4 | guerrero negro.
# Processing record 42 of set 4 | nanortalik.
# Processing record 43 of set 4 | siilinjarvi.
# Processing record 44 of set 4 | camacha.
# Processing record 45 of set 4 | alice springs.
# Processing record 46 of set 4 | buchanan.
# Processing record 47 of set 4 | ruwi.
# Processing record 48 of set 4 | buala.
# Processing record 49 of set 4 | northam.
# Processing record 50 of set 4 | negombo.
# Processing record 1 of set 5 | shubarkuduk.
# Processing record 2 of set 5 | villa carlos paz.
# Processing record 3 of set 5 | rudnogorsk.
# Processing record 4 of set 5 | talara.
# Processing record 5 of set 5 | krasnoselkup.
# Processing record 6 of set 5 | gewane.
# Processing record 7 of set 5 | chernyshevskiy.
# Processing record 8 of set 5 | touros.
# Processing record 9 of set 5 | bundaberg.
# Processing record 10 of set 5 | mehamn.
# Processing record 11 of set 5 | trofors.
# Processing record 12 of set 5 | saryshagan.
# Unable to complete record. Checking next city.
# Processing record 13 of set 5 | tumannyy.
# Unable to complete record. Checking next city.
# Processing record 14 of set 5 | bambous virieux.
# Processing record 15 of set 5 | matara.
# Processing record 16 of set 5 | stege.
# Processing record 17 of set 5 | tucurui.
# Processing record 18 of set 5 | port elizabeth.
# Processing record 19 of set 5 | port blair.
# Processing record 20 of set 5 | sitka.
# Processing record 21 of set 5 | kieta.
# Processing record 22 of set 5 | xixiang.
# Processing record 23 of set 5 | alekseyevsk.
# Processing record 24 of set 5 | chipoka.
# Processing record 25 of set 5 | hovd.
# Processing record 26 of set 5 | lebyazhye.
# Processing record 27 of set 5 | umm kaddadah.
# Processing record 28 of set 5 | kavieng.
# Processing record 29 of set 5 | awbari.
# Processing record 30 of set 5 | mahebourg.
# Processing record 31 of set 5 | ranong.
# Processing record 32 of set 5 | lebu.
# Processing record 33 of set 5 | solovetskiy.
# Unable to complete record. Checking next city.
# Processing record 34 of set 5 | solnechnyy.
# Processing record 35 of set 5 | jacksonville.
# Processing record 36 of set 5 | zhanaozen.
# Processing record 37 of set 5 | amderma.
# Unable to complete record. Checking next city.
# Processing record 38 of set 5 | kudahuvadhoo.
# Processing record 39 of set 5 | veracruz.
# Processing record 40 of set 5 | bilma.
# Processing record 41 of set 5 | kibre mengist.
# Processing record 42 of set 5 | gazalkent.
# Processing record 43 of set 5 | mizdah.
# Processing record 44 of set 5 | turukhansk.
# Processing record 45 of set 5 | petrov val.
# Processing record 46 of set 5 | guamuchil.
# Processing record 47 of set 5 | georgetown.
# Processing record 48 of set 5 | xalpatlahuac.
# Processing record 49 of set 5 | cagayan de tawi-tawi.
# Unable to complete record. Checking next city.
# Processing record 50 of set 5 | hualmay.
# Processing record 1 of set 6 | ostersund.
# Processing record 2 of set 6 | omurtag.
# Processing record 3 of set 6 | bow island.
# Processing record 4 of set 6 | diego de almagro.
# Processing record 5 of set 6 | kayes.
# Processing record 6 of set 6 | asilah.
# Processing record 7 of set 6 | hirara.
# Processing record 8 of set 6 | gaogou.
# Processing record 9 of set 6 | odlabari.
# Processing record 10 of set 6 | tiarei.
# Processing record 11 of set 6 | amahai.
# Processing record 12 of set 6 | lolua.
# Unable to complete record. Checking next city.
# Processing record 13 of set 6 | kaitangata.
# Processing record 14 of set 6 | esperance.
# Processing record 15 of set 6 | jaggayyapeta.
# Processing record 16 of set 6 | kanigoro.
# Processing record 17 of set 6 | salalah.
# Processing record 18 of set 6 | oranjemund.
# Processing record 19 of set 6 | sioni.
# Processing record 20 of set 6 | sao filipe.
# Processing record 21 of set 6 | strezhevoy.
# Processing record 22 of set 6 | binzhou.
# Processing record 23 of set 6 | kerouane.
# Processing record 24 of set 6 | wanning.
# Processing record 25 of set 6 | morgantown.
# Processing record 26 of set 6 | iranshahr.
# Processing record 27 of set 6 | sheregesh.
# Processing record 28 of set 6 | roald.
# Processing record 29 of set 6 | bukama.
# Processing record 30 of set 6 | tomatlan.
# Processing record 31 of set 6 | shahreza.
# Processing record 32 of set 6 | ahipara.
# Processing record 33 of set 6 | tete.
# Processing record 34 of set 6 | madera.
# Processing record 35 of set 6 | neepawa.
# Processing record 36 of set 6 | spencer.
# Processing record 37 of set 6 | fort nelson.
# Processing record 38 of set 6 | cabo san lucas.
# Processing record 39 of set 6 | raudeberg.
# Processing record 40 of set 6 | taoudenni.
# Processing record 41 of set 6 | san patricio.
# Processing record 42 of set 6 | san carlos.
# Processing record 43 of set 6 | posse.
# Processing record 44 of set 6 | garowe.
# Processing record 45 of set 6 | trenggalek.
# Processing record 46 of set 6 | tekirdag.
# Processing record 47 of set 6 | narsaq.
# Processing record 48 of set 6 | mondovi.
# Processing record 49 of set 6 | dunedin.
# Processing record 50 of set 6 | leshukonskoye.
# Processing record 1 of set 7 | ucluelet.
# Processing record 2 of set 7 | portland.
# Processing record 3 of set 7 | darlowo.
# Processing record 4 of set 7 | tabou.
# Processing record 5 of set 7 | goderich.
# Processing record 6 of set 7 | carnarvon.
# Processing record 7 of set 7 | bereda.
# Processing record 8 of set 7 | tombouctou.
# Processing record 9 of set 7 | manzhouli.
# Processing record 10 of set 7 | nassau.
# Processing record 11 of set 7 | tawnat.
# Unable to complete record. Checking next city.
# Processing record 12 of set 7 | amga.
# Processing record 13 of set 7 | boshnyakovo.
# Processing record 14 of set 7 | vila franca do campo.
# Processing record 15 of set 7 | kjopsvik.
# Processing record 16 of set 7 | santa catarina mita.
# Processing record 17 of set 7 | mandera.
# Processing record 18 of set 7 | maragogi.
# Processing record 19 of set 7 | vao.
# Processing record 20 of set 7 | aripuana.
# Processing record 21 of set 7 | severodvinsk.
# Processing record 22 of set 7 | humaita.
# Processing record 23 of set 7 | mitzic.
# Processing record 24 of set 7 | mahon.
# Processing record 25 of set 7 | dunda.
# Processing record 26 of set 7 | sayyan.
# Processing record 27 of set 7 | coquimbo.
# Processing record 28 of set 7 | calbe.
# Processing record 29 of set 7 | acuna.
# Unable to complete record. Checking next city.
# Processing record 30 of set 7 | kununurra.
# Processing record 31 of set 7 | kodiak.
# Processing record 32 of set 7 | duluth.
# Processing record 33 of set 7 | misratah.
# Processing record 34 of set 7 | kokkola.
# Processing record 35 of set 7 | ahumada.
# Unable to complete record. Checking next city.
# Processing record 36 of set 7 | papayal.
# Processing record 37 of set 7 | dzhusaly.
# Unable to complete record. Checking next city.
# Processing record 38 of set 7 | istok.
# Processing record 39 of set 7 | felidhoo.
# Unable to complete record. Checking next city.
# Processing record 40 of set 7 | launceston.
# Processing record 41 of set 7 | hay river.
# Processing record 42 of set 7 | svetlogorsk.
# Processing record 43 of set 7 | maniitsoq.
# Processing record 44 of set 7 | broken hill.
# Processing record 45 of set 7 | chicama.
# Processing record 46 of set 7 | boden.
# Processing record 47 of set 7 | whitehorse.
# Processing record 48 of set 7 | acarau.
# Processing record 49 of set 7 | sargatskoye.
# Processing record 50 of set 7 | vavatenina.
# Processing record 1 of set 8 | souillac.
# Processing record 2 of set 8 | kuito.
# Processing record 3 of set 8 | taylor.
# Processing record 4 of set 8 | moranbah.
# Processing record 5 of set 8 | port-cartier.
# Processing record 6 of set 8 | palabuhanratu.
# Unable to complete record. Checking next city.
# Processing record 7 of set 8 | aguas vermelhas.
# Processing record 8 of set 8 | middelharnis.
# Processing record 9 of set 8 | torbay.
# Processing record 10 of set 8 | monrovia.
# Processing record 11 of set 8 | faya.
# Processing record 12 of set 8 | atbasar.
# Processing record 13 of set 8 | shingu.
# Processing record 14 of set 8 | komsomolskiy.
# Processing record 15 of set 8 | norman wells.
# Processing record 16 of set 8 | cotonou.
# Processing record 17 of set 8 | huancavelica.
# Processing record 18 of set 8 | fairbanks.
# Processing record 19 of set 8 | saint-augustin.
# Processing record 20 of set 8 | khandyga.
# Processing record 21 of set 8 | lebedyn.
# Processing record 22 of set 8 | north bend.
# Processing record 23 of set 8 | anadyr.
# Processing record 24 of set 8 | cayenne.
# Processing record 25 of set 8 | usinsk.
# Processing record 26 of set 8 | inderborskiy.
# Unable to complete record. Checking next city.
# Processing record 27 of set 8 | palmer.
# Processing record 28 of set 8 | san quintin.
# Processing record 29 of set 8 | clyde river.
# Processing record 30 of set 8 | pangnirtung.
# Processing record 31 of set 8 | leh.
# Processing record 32 of set 8 | upernavik.
# Processing record 33 of set 8 | ksenyevka.
# Unable to complete record. Checking next city.
# Processing record 34 of set 8 | karauzyak.
# Unable to complete record. Checking next city.
# Processing record 35 of set 8 | rincon.
# Processing record 36 of set 8 | holme.
# Processing record 37 of set 8 | bogorodskoye.
# Processing record 38 of set 8 | mogadishu.
# Processing record 39 of set 8 | mineiros.
# Processing record 40 of set 8 | katsuura.
# Processing record 41 of set 8 | gornopravdinsk.
# Processing record 42 of set 8 | port macquarie.
# Processing record 43 of set 8 | cumaribo.
# Unable to complete record. Checking next city.
# Processing record 44 of set 8 | ijui.
# Processing record 45 of set 8 | coolum beach.
# Processing record 46 of set 8 | cairo montenotte.
# Processing record 47 of set 8 | lorengau.
# Processing record 48 of set 8 | evensk.
# Processing record 49 of set 8 | camacari.
# Processing record 50 of set 8 | kruisfontein.
# Processing record 1 of set 9 | umzimvubu.
# Unable to complete record. Checking next city.
# Processing record 2 of set 9 | jumla.
# Processing record 3 of set 9 | orocue.
# Processing record 4 of set 9 | louisbourg.
# Unable to complete record. Checking next city.
# Processing record 5 of set 9 | zeya.
# Processing record 6 of set 9 | jalu.
# Processing record 7 of set 9 | madimba.
# Processing record 8 of set 9 | itoman.
# Processing record 9 of set 9 | atar.
# Processing record 10 of set 9 | guane.
# Processing record 11 of set 9 | hamilton.
# Processing record 12 of set 9 | leningradskiy.
# Processing record 13 of set 9 | diffa.
# Processing record 14 of set 9 | leeton.
# Processing record 15 of set 9 | vostok.
# Processing record 16 of set 9 | barentsburg.
# Unable to complete record. Checking next city.
# Processing record 17 of set 9 | panaba.
# Processing record 18 of set 9 | potgietersrus.
# Unable to complete record. Checking next city.
# Processing record 19 of set 9 | luderitz.
# Processing record 20 of set 9 | san policarpo.
# Processing record 21 of set 9 | aflu.
# Unable to complete record. Checking next city.
# Processing record 22 of set 9 | longyearbyen.
# Processing record 23 of set 9 | port arthur.
# Processing record 24 of set 9 | ust-nera.
# Processing record 25 of set 9 | pasir gudang.
# Processing record 26 of set 9 | aldan.
# Processing record 27 of set 9 | hoopstad.
# Processing record 28 of set 9 | san cristobal.
# Processing record 29 of set 9 | wajir.
# Processing record 30 of set 9 | novyy urgal.
# Processing record 31 of set 9 | altay.
# Processing record 32 of set 9 | brajrajnagar.
# Unable to complete record. Checking next city.
# Processing record 33 of set 9 | kintampo.
# Processing record 34 of set 9 | batagay.
# Processing record 35 of set 9 | lata.
# Processing record 36 of set 9 | capinota.
# Processing record 37 of set 9 | cockburn town.
# Processing record 38 of set 9 | udachnyy.
# Processing record 39 of set 9 | karasjok.
# Processing record 40 of set 9 | aasiaat.
# Processing record 41 of set 9 | pervomaysk.
# Processing record 42 of set 9 | boende.
# Processing record 43 of set 9 | sobolevo.
# Processing record 44 of set 9 | liwale.
# Processing record 45 of set 9 | harper.
# Processing record 46 of set 9 | paramonga.
# Processing record 47 of set 9 | bargal.
# Unable to complete record. Checking next city.
# Processing record 48 of set 9 | hwange.
# Processing record 49 of set 9 | bay roberts.
# Processing record 50 of set 9 | la ronge.
# Processing record 1 of set 10 | pala.
# Processing record 2 of set 10 | aykhal.
# Processing record 3 of set 10 | helong.
# Processing record 4 of set 10 | champerico.
# Processing record 5 of set 10 | el dorado.
# Processing record 6 of set 10 | teahupoo.
# Processing record 7 of set 10 | broome.
# Processing record 8 of set 10 | samusu.
# Unable to complete record. Checking next city.
# Processing record 9 of set 10 | inongo.
# Processing record 10 of set 10 | lujiang.
# Processing record 11 of set 10 | ende.
# Processing record 12 of set 10 | charters towers.
# Processing record 13 of set 10 | kaeo.
# Processing record 14 of set 10 | conceicao das alagoas.
# Processing record 15 of set 10 | weligama.
# Processing record 16 of set 10 | pyu.
# Processing record 17 of set 10 | codrington.
# Processing record 18 of set 10 | puerto carreno.
# Processing record 19 of set 10 | saint-andre-avellin.
# Processing record 20 of set 10 | mirandola.
# Processing record 21 of set 10 | beyneu.
# Processing record 22 of set 10 | utmanzai.
# Processing record 23 of set 10 | raga.
# Processing record 24 of set 10 | neryungri.
# Processing record 25 of set 10 | vaiano.
# Processing record 26 of set 10 | sandwick.
# Processing record 27 of set 10 | tlaltenango.
# Processing record 28 of set 10 | kommunisticheskiy.
# Processing record 29 of set 10 | gyula.
# Processing record 30 of set 10 | warqla.
# Unable to complete record. Checking next city.
# Processing record 31 of set 10 | namibe.
# Processing record 32 of set 10 | caluquembe.
# Processing record 33 of set 10 | nago.
# Processing record 34 of set 10 | mendoza.
# Processing record 35 of set 10 | nemuro.
# Processing record 36 of set 10 | prainha.
# Processing record 37 of set 10 | rocha.
# Processing record 38 of set 10 | kavaratti.
# Processing record 39 of set 10 | eureka.
# Processing record 40 of set 10 | falaleu.
# Unable to complete record. Checking next city.
# Processing record 41 of set 10 | xining.
# Processing record 42 of set 10 | saravan.
# Processing record 43 of set 10 | neijiang.
# Processing record 44 of set 10 | samalaeulu.
# Unable to complete record. Checking next city.
# Processing record 45 of set 10 | necochea.
# Processing record 46 of set 10 | tumut.
# Processing record 47 of set 10 | kailua.
# Processing record 48 of set 10 | inzer.
# Processing record 49 of set 10 | sola.
# Processing record 50 of set 10 | kihei.
# Processing record 1 of set 11 | jinchang.
# Processing record 2 of set 11 | tunduru.
# Unable to complete record. Checking next city.
# Processing record 3 of set 11 | dhidhdhoo.
# Processing record 4 of set 11 | alofi.
# Processing record 5 of set 11 | juybar.
# Processing record 6 of set 11 | gizo.
# Processing record 7 of set 11 | fort saint james.
# Processing record 8 of set 11 | marrakesh.
# Processing record 9 of set 11 | red wing.
# Processing record 10 of set 11 | vaitupu.
# Unable to complete record. Checking next city.
# Processing record 11 of set 11 | sandy bay.
# Processing record 12 of set 11 | zhanakorgan.
# Processing record 13 of set 11 | pindwara.
# Processing record 14 of set 11 | xam nua.
# Processing record 15 of set 11 | china.
# Processing record 16 of set 11 | paamiut.
# Processing record 17 of set 11 | namatanai.
# Processing record 18 of set 11 | otukpo.
# Processing record 19 of set 11 | santa rosa.
# Processing record 20 of set 11 | lagoa.
# Processing record 21 of set 11 | nisia floresta.
# Processing record 22 of set 11 | tapaua.
# Unable to complete record. Checking next city.
# Processing record 23 of set 11 | urdzhar.
# Unable to complete record. Checking next city.
# Processing record 24 of set 11 | maceio.
# Processing record 25 of set 11 | chaadayevka.
# Processing record 26 of set 11 | chimbote.
# Processing record 27 of set 11 | kulhudhuffushi.
# Processing record 28 of set 11 | krasnolesnyy.
# Processing record 29 of set 11 | taree.
# Processing record 30 of set 11 | katubao.
# Processing record 31 of set 11 | bridlington.
# Processing record 32 of set 11 | jiblah.
# Processing record 33 of set 11 | turka.
# Processing record 34 of set 11 | oktyabrskoye.
# Processing record 35 of set 11 | saldanha.
# Processing record 36 of set 11 | asau.
# Processing record 37 of set 11 | mashhad.
# Processing record 38 of set 11 | poum.
# Processing record 39 of set 11 | dogondoutchi.
# Processing record 40 of set 11 | contamana.
# Processing record 41 of set 11 | almeirim.
# Processing record 42 of set 11 | stokmarknes.
# Processing record 43 of set 11 | vanimo.
# Processing record 44 of set 11 | ovsyanka.
# Processing record 45 of set 11 | fomboni.
# Processing record 46 of set 11 | vestmanna.
# Processing record 47 of set 11 | keuruu.
# Processing record 48 of set 11 | viligili.
# Unable to complete record. Checking next city.
# Processing record 49 of set 11 | bandarbeyla.
# Processing record 50 of set 11 | oksfjord.
# Processing record 1 of set 12 | davila.
# Processing record 2 of set 12 | alugan.
# Processing record 3 of set 12 | vestmannaeyjar.
# Processing record 4 of set 12 | troitsko-pechorsk.
# Processing record 5 of set 12 | ambagarh chauki.
# Processing record 6 of set 12 | burica.
# Unable to complete record. Checking next city.
# Processing record 7 of set 12 | uruguaiana.
# Processing record 8 of set 12 | the valley.
# Processing record 9 of set 12 | tura.
# Processing record 10 of set 12 | caceres.
# Processing record 11 of set 12 | bikramganj.
# Processing record 12 of set 12 | trincomalee.
# Processing record 13 of set 12 | lompoc.
# Processing record 14 of set 12 | sechura.
# Processing record 15 of set 12 | serebryanyy bor.
# Processing record 16 of set 12 | comodoro rivadavia.
# Processing record 17 of set 12 | rio gallegos.
# Processing record 18 of set 12 | amapa.
# Processing record 19 of set 12 | carmen.
# Processing record 20 of set 12 | toora-khem.
# Processing record 21 of set 12 | kupang.
# Processing record 22 of set 12 | labrea.
# Processing record 23 of set 12 | brae.
# Processing record 24 of set 12 | quatre cocos.
# Processing record 25 of set 12 | melfi.
# Processing record 26 of set 12 | grand river south east.
# Unable to complete record. Checking next city.
# Processing record 27 of set 12 | villazon.
# Processing record 28 of set 12 | buraydah.
# Processing record 29 of set 12 | bakel.
# Processing record 30 of set 12 | barcelona.
# Processing record 31 of set 12 | puerto plata.
# Processing record 32 of set 12 | sterling.
# Processing record 33 of set 12 | kutum.
# Processing record 34 of set 12 | naze.
# Processing record 35 of set 12 | batagay-alyta.
# Processing record 36 of set 12 | ivanteyevka.
# Processing record 37 of set 12 | huarmey.
# Processing record 38 of set 12 | durban.
# Processing record 39 of set 12 | ustka.
# Processing record 40 of set 12 | ikalamavony.
# Processing record 41 of set 12 | fortuna.
# Processing record 42 of set 12 | agnibilekrou.
# Processing record 43 of set 12 | qaqortoq.
# Processing record 44 of set 12 | dakar.
# Processing record 45 of set 12 | jadu.
# Processing record 46 of set 12 | san blas.
# Processing record 47 of set 12 | tezu.
# Processing record 48 of set 12 | agirish.
# Processing record 49 of set 12 | scottsbluff.
# Processing record 50 of set 12 | kingaroy.
# Processing record 1 of set 13 | chagda.
# Unable to complete record. Checking next city.
# Processing record 2 of set 13 | haines junction.
# Processing record 3 of set 13 | rungata.
# Unable to complete record. Checking next city.
# Processing record 4 of set 13 | ampanihy.
# Processing record 5 of set 13 | kosh-agach.
# Processing record 6 of set 13 | puerto colombia.
# Processing record 7 of set 13 | pangoa.
# Processing record 8 of set 13 | gazimurskiy zavod.
# Processing record 9 of set 13 | severo-kurilsk.
# Processing record 10 of set 13 | gat.
# Processing record 11 of set 13 | koscierzyna.
# Processing record 12 of set 13 | sandomierz.
# Processing record 13 of set 13 | clearlake.
# Processing record 14 of set 13 | miram shah.
# Processing record 15 of set 13 | sorvag.
# Unable to complete record. Checking next city.
# Processing record 16 of set 13 | taclobo.
# Processing record 17 of set 13 | mykhaylivka.
# Processing record 18 of set 13 | birjand.
# Processing record 19 of set 13 | qasigiannguit.
# Processing record 20 of set 13 | zhezkazgan.
# Processing record 21 of set 13 | igarka.
# Processing record 22 of set 13 | athabasca.
# Processing record 23 of set 13 | orbetello.
# Processing record 24 of set 13 | yerbogachen.
# Processing record 25 of set 13 | bolshaya glushitsa.
# Processing record 26 of set 13 | nouadhibou.
# Processing record 27 of set 13 | bagdarin.
# Processing record 28 of set 13 | yenagoa.
# Processing record 29 of set 13 | oussouye.
# Processing record 30 of set 13 | adre.
# Processing record 31 of set 13 | barroso.
# Processing record 32 of set 13 | yemelyanovo.
# Processing record 33 of set 13 | yuzhno-yeniseyskiy.
# Unable to complete record. Checking next city.
# Processing record 34 of set 13 | tabiauea.
# Unable to complete record. Checking next city.
# Processing record 35 of set 13 | mazatlan.
# Processing record 36 of set 13 | arman.
# Processing record 37 of set 13 | armacao dos buzios.
# Unable to complete record. Checking next city.
# Processing record 38 of set 13 | kampong thum.
# Data Retrieval Complete.

# %% [markdown]
# ### Convert to DataFrame and Export

# %%
# convert the weather data array into a dataframe
weather_data_df = me.DataFrame(weather_data)
weather_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloud Cover  \
# 0  Punta Arenas -53.1500 -70.9167     35.71        60            0
# 1      Hermanus -34.4187  19.2345     51.80        60            0
# 2      Rajshahi  24.3667  88.6000     78.37        90          100
# 3      Yarmouth  41.7057 -70.2286     81.07        88          100
# 4          Chui -33.6971 -53.4616     58.08        97          100
#
#    Wind Speed Country
# 0       13.80      CL
# 1        8.61      ZA
# 2        5.53      BD
# 3       19.57      US
# 4        8.99      UY

# %%
# output data to csv wtihout index column
weather_data_df.to_csv(output_data_csv, index=False)

# %% [markdown]
# ### Inspect Cities For Humidity Over 100%

# %%
# check to see if any cities have > 100% humidity by checking max values via describe
weather_data_df.describe()

# there are no cities with humidity over 100% based on max temp max value
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloud Cover  Wind Speed
# count  581.000000  581.000000  581.000000  581.000000   581.000000  581.000000
# mean    21.457648   17.628215   68.939139   73.820998    53.061962    7.819157
# std     33.023020   89.119752   13.756530   20.341455    38.749099    5.630345
# min    -54.800000 -175.200000   30.150000    8.000000     0.000000    0.000000
# 25%     -7.258600  -60.633300   59.360000   64.000000    13.000000    3.510000
# 50%     25.466700   18.423200   71.290000   80.000000    55.000000    6.400000
# 75%     50.033400   92.676700   78.780000   89.000000    93.000000   10.490000
# max     78.218600  178.416700  105.390000  100.000000   100.000000   32.210000

# %% [markdown]
# ### Graphing Results

# %% [markdown]
# #### Latitude vs. Temperature

# %%
plt.figure(figsize=(10, 6))
plt.scatter(weather_data_df['Lat'], weather_data_df['Max Temp'], s=30, color='tab:red', edgecolors='gray')
plt.title(f'Latitude vs. Maximum Temperature for {len(weather_data_df)} cities \n(Data retrieved via the OpenWeather API on {today})')
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Maximum Temperature (°F)', fontsize=12)
plt.xlim(-90, 90)
plt.savefig("images/LATvTEMP.png")
plt.show()

# %% [markdown]
# #### Maximum Temperature (°F) by Location

# %%
plt.figure(figsize=(10, 6))
plt.scatter(weather_data_df['Lng'],weather_data_df['Lat'], c=weather_data_df['Max Temp'], s=30, 
            cmap='coolwarm', edgecolors='gray')
plt.title(f'Maximum Temperature (°F) by City Location by {len(weather_data_df)} cities \n(Data retrieved via the OpenWeather API on {today})')
plt.xlabel('Longitude', fontsize=12)
plt.ylabel('Latitude', fontsize=12)
plt.xlim(-190, 190)
plt.ylim(-90, 90)
plt.colorbar()
plt.savefig("images/LOCvTEMP.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity

# %%
plt.figure(figsize=(10, 6))
plt.scatter(weather_data_df['Lat'], weather_data_df['Humidity'], s=30, color='tab:red', edgecolors='gray')
plt.title(f'Latitude vs. Humidity (%) for {len(weather_data_df)} cities \n(Data retrieved via the OpenWeather API on {today})')
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Humidity (%)', fontsize=12)
plt.xlim(-90, 90)
plt.savefig("images/LATvHUM.png")
plt.show()

# %% [markdown]
# #### Humidity (%) by Location

# %%
plt.figure(figsize=(10, 6))
plt.scatter(weather_data_df['Lng'],weather_data_df['Lat'], c=weather_data_df['Humidity'], s=30, 
            cmap='coolwarm', edgecolors='gray')
plt.title(f'Humidity (%) by City Location by {len(weather_data_df)} cities \n(Data retrieved via the OpenWeather API on {today})')
plt.xlabel('Longitude', fontsize=12)
plt.ylabel('Latitude', fontsize=12)
plt.xlim(-190, 190)
plt.ylim(-90, 90)
plt.colorbar()
plt.savefig("images/LOCvHUM.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloud Cover

# %%
plt.figure(figsize=(10, 6))
plt.scatter(weather_data_df['Lat'], weather_data_df['Cloud Cover'], s=30, color='tab:cyan', edgecolors='gray')
plt.title(f'Latitude vs. Cloud Cover (%) for {len(weather_data_df)} cities \n(Data retrieved via the OpenWeather API on {today})')
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Cloud Cover (%)', fontsize=12)
plt.xlim(-90, 90)
plt.savefig("images/LATvCLD.png")
plt.show()

# %% [markdown]
# #### Cloud Cover (%) by Location

# %%
plt.figure(figsize=(10, 6))
plt.scatter(weather_data_df['Lng'],weather_data_df['Lat'], c=weather_data_df['Cloud Cover'], s=30, 
            cmap='Blues', edgecolors='gray')
plt.title(f'Cloud Cover (%) by City Location by {len(weather_data_df)} cities \n(Data retrieved via the OpenWeather API on {today})')
plt.xlabel('Longitude', fontsize=12)
plt.ylabel('Latitude', fontsize=12)
plt.xlim(-190, 190)
plt.ylim(-90, 90)
plt.colorbar()
plt.savefig("images/LOCvCLD.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed (mph)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(weather_data_df['Lat'], weather_data_df['Wind Speed'], s=30, color='tab:green', edgecolors='gray')
plt.title(f'Latitude vs. Wind Speed (mph) for {len(weather_data_df)} cities \n(Data retrieved via the OpenWeather API on {today})')
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('Wind Speed (mph)', fontsize=12)
plt.xlim(-90, 90)
plt.savefig("images/LATvWND.png")
plt.show()

# %% [markdown]
# #### Wind Speed (mph) by Location

# %%
plt.figure(figsize=(10, 6))
plt.scatter(weather_data_df['Lng'],weather_data_df['Lat'], c=weather_data_df['Wind Speed'], s=30, 
            cmap='jet', edgecolors='gray')
plt.title(f'Wind Speed (mph) by City Location by {len(weather_data_df)} cities \n(Data retrieved via the OpenWeather API on {today})')
plt.xlabel('Longitude', fontsize=12, fontweight='bold')
plt.ylabel('Latitude', fontsize=12, fontweight='bold')
plt.xlim(-190, 190)
plt.ylim(-90, 90)
plt.colorbar()
plt.savefig("images/LOCvWND.png")
plt.show()

# %% [markdown]
# ### Linear Regression Models

# %%
# split dataframe between northern and southern hemispheres
# northern hemisphere where latitude >= 0
northern_hemi_df = weather_data_df.loc[weather_data_df['Lat'] >= 0]

# southern hemisphere where latitued < 0
southern_hemi_df = weather_data_df.loc[weather_data_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# calculated the correlation coefficient and linear regression model for northern hemisphere maximum temperature versus
# latitude

# set variables (northern) for regression modelling
n_lati = northern_hemi_df['Lat']
n_temp = northern_hemi_df['Max Temp']
n_xVals = n_lati
n_yVals = n_temp

# correlation and regression
corr = st.pearsonr(n_temp, n_lati)
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_xVals, n_yVals)
regressVals = n_xVals * slope + intercept
lineEQ = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

print(f"The correlation between maximum temperature and latitude is {round(corr[0],4)}.")
print(f"The r-squared value is: {round(rvalue**2, 4)}.")

plt.figure(figsize=(10, 6))
plt.scatter(n_xVals, n_yVals, s=30, color='tab:red', edgecolors='gray')
plt.plot(n_xVals, regressVals, 'k-', alpha=0.5)
plt.annotate(lineEQ, xy=(0, 40), fontsize=12, color='k')
plt.title('Latitude vs. Max. Temp. (Northern Hemisphere)', fontsize=14, fontweight='bold')
plt.xlabel('Latitude', fontsize=12, fontweight='bold')
plt.ylabel('Maximum Temperature (°F)', fontsize=12, fontweight='bold')
plt.savefig("images/LATvTEMP_northern.png")
plt.show()
# Out:
# The correlation between maximum temperature and latitude is -0.6429.
# The r-squared value is: 0.4134.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# calculated the correlation coefficient and linear regression model for southern hemisphere maximum temperature versus
# latitude

# set variables (northern) for regression modelling
s_lati = southern_hemi_df['Lat']
s_temp = southern_hemi_df['Max Temp']
s_xVals = s_lati
s_yVals = s_temp

# correlation and regression
corr = st.pearsonr(s_temp, s_lati)
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_xVals, s_yVals)
regressVals = s_xVals * slope + intercept
lineEQ = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

print(f"The correlation between maximum temperature and latitude is {round(corr[0],4)}.")
print(f"The r-squared value is: {round(rvalue**2, 4)}.")

plt.figure(figsize=(10, 6))
plt.scatter(s_xVals, s_yVals, s=30, color='tab:red', edgecolors='gray')
plt.plot(s_xVals, regressVals, 'k-', alpha=0.5)
plt.annotate(lineEQ, xy=(-55, 95), fontsize=12, color='k')
plt.title('Latitude vs. Max. Temp. (Southern Hemisphere)', fontsize=14, fontweight='bold')
plt.xlabel('Latitude', fontsize=12, fontweight='bold')
plt.ylabel('Maximum Temperature (°F)', fontsize=12, fontweight='bold')
plt.savefig("images/LATvTEMP_southern.png")
plt.show()
# Out:
# The correlation between maximum temperature and latitude is 0.7747.
# The r-squared value is: 0.6001.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# calculated the correlation coefficient and linear regression model for northern hemisphere humidity versus
# latitude

# set variables (northern) for regression modelling
n_lati = northern_hemi_df['Lat']
n_hum = northern_hemi_df['Humidity']
n_xVals = n_lati
n_yVals = n_hum

# correlation and regression
corr = st.pearsonr(n_hum, n_lati)
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_xVals, n_yVals)
regressVals = n_xVals * slope + intercept
lineEQ = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

print(f"The correlation between humidity and latitude is {round(corr[0],4)}.")
print(f"The r-squared value is: {round(rvalue**2, 4)}.")

plt.figure(figsize=(10, 6))
plt.scatter(n_xVals, n_yVals, s=30, color='tab:red', edgecolors='gray')
plt.plot(n_xVals, regressVals, 'k-', alpha=0.5)
plt.annotate(lineEQ, xy=(60, 10), fontsize=12, color='k')
plt.title('Latitude vs. Humidity (Northern Hemisphere)', fontsize=14, fontweight='bold')
plt.xlabel('Latitude', fontsize=12, fontweight='bold')
plt.ylabel('Humidity (%)', fontsize=12, fontweight='bold')
plt.savefig("images/LATvHUM_northern.png")
plt.show()
# Out:
# The correlation between humidity and latitude is 0.0537.
# The r-squared value is: 0.0029.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# calculated the correlation coefficient and linear regression model for southern hemisphere humidity versus
# latitude

# set variables (northern) for regression modelling
s_lati = southern_hemi_df['Lat']
s_hum = southern_hemi_df['Humidity']
s_xVals = s_lati
s_yVals = s_hum

# correlation and regression
corr = st.pearsonr(s_hum, s_lati)
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_xVals, s_yVals)
regressVals = s_xVals * slope + intercept
lineEQ = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

print(f"The correlation between humidity and latitude is {round(corr[0],4)}.")
print(f"The r-squared value is: {round(rvalue**2, 4)}.")

plt.figure(figsize=(10, 6))
plt.scatter(s_xVals, s_yVals, s=30, color='tab:red', edgecolors='gray')
plt.plot(s_xVals, regressVals, 'k-', alpha=0.5)
plt.annotate(lineEQ, xy=(60, 10), fontsize=12, color='k')
plt.title('Latitude vs. Humidity (Southern Hemisphere)', fontsize=14, fontweight='bold')
plt.xlabel('Latitude', fontsize=12, fontweight='bold')
plt.ylabel('Humidity (%)', fontsize=12, fontweight='bold')
plt.savefig("images/LATvHUM_southern.png")
plt.show()
# Out:
# The correlation between humidity and latitude is -0.1448.
# The r-squared value is: 0.021.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# calculated the correlation coefficient and linear regression model for northern hemisphere cloud cover versus
# latitude

# set variables (northern) for regression modelling
n_lati = northern_hemi_df['Lat']
n_cloud = northern_hemi_df['Cloud Cover']
n_xVals = n_lati
n_yVals = n_cloud

# correlation and regression
corr = st.pearsonr(n_hum, n_cloud)
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_xVals, n_yVals)
regressVals = n_xVals * slope + intercept
lineEQ = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

print(f"The correlation between cloud cover and latitude is {round(corr[0],4)}.")
print(f"The r-squared value is: {round(rvalue**2, 4)}.")

plt.figure(figsize=(10, 6))
plt.scatter(n_xVals, n_yVals, s=30, color='tab:cyan', edgecolors='gray')
plt.plot(n_xVals, regressVals, 'k-', alpha=0.5)
plt.annotate(lineEQ, xy=(0, 6), fontsize=12, color='k')
plt.title('Latitude vs. Cloud Cover (Northern Hemisphere)', fontsize=14, fontweight='bold')
plt.xlabel('Latitude', fontsize=12, fontweight='bold')
plt.ylabel('Cloud Cover (%)', fontsize=12, fontweight='bold')
plt.savefig("images/LATvCLD_northern.png")
plt.show()
# Out:
# The correlation between cloud cover and latitude is 0.3524.
# The r-squared value is: 0.0007.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# calculated the correlation coefficient and linear regression model for southern hemisphere cloud cover versus
# latitude

# set variables (northern) for regression modelling
s_lati = southern_hemi_df['Lat']
s_cloud = southern_hemi_df['Cloud Cover']
s_xVals = s_lati
s_yVals = s_cloud

# correlation and regression
corr = st.pearsonr(s_hum, s_cloud)
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_xVals, s_yVals)
regressVals = s_xVals * slope + intercept
lineEQ = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

print(f"The correlation between cloud cover and latitude is {round(corr[0],4)}.")
print(f"The r-squared value is: {round(rvalue**2, 4)}.")

plt.figure(figsize=(10, 6))
plt.scatter(s_xVals, s_yVals, s=30, color='tab:cyan', edgecolors='gray')
plt.plot(s_xVals, regressVals, 'k-', alpha=0.5)
plt.annotate(lineEQ, xy=(60, 10), fontsize=12, color='k')
plt.title('Latitude vs. Cloud Cover (Southern Hemisphere)', fontsize=14, fontweight='bold')
plt.xlabel('Latitude', fontsize=12, fontweight='bold')
plt.ylabel('Cloud Cover (%)', fontsize=12, fontweight='bold')
plt.savefig("images/LATvCLD_southern.png")
plt.show()
# Out:
# The correlation between cloud cover and latitude is 0.449.
# The r-squared value is: 0.0013.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# calculated the correlation coefficient and linear regression model for northern hemisphere wind speed versus
# latitude

# set variables (northern) for regression modelling
n_lati = northern_hemi_df['Lat']
n_wind = northern_hemi_df['Wind Speed']
n_xVals = n_lati
n_yVals = n_wind

# correlation and regression
corr = st.pearsonr(n_hum, n_wind)
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_xVals, n_yVals)
regressVals = n_xVals * slope + intercept
lineEQ = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

print(f"The correlation between wind speed and latitude is {round(corr[0],4)}.")
print(f"The r-squared value is: {round(rvalue**2, 4)}.")

plt.figure(figsize=(10, 6))
plt.scatter(n_xVals, n_yVals, s=30, color='tab:green', edgecolors='gray')
plt.plot(n_xVals, regressVals, 'k-', alpha=0.5)
plt.annotate(lineEQ, xy=(60, 30), fontsize=12, color='k')
plt.title('Latitude vs. Wind Speed (Northern Hemisphere)', fontsize=14, fontweight='bold')
plt.xlabel('Latitude', fontsize=12, fontweight='bold')
plt.ylabel('Wind Speed (mph)', fontsize=12, fontweight='bold')
plt.savefig("images/LATvWND_northern.png")
plt.show()
# Out:
# The correlation between wind speed and latitude is -0.177.
# The r-squared value is: 0.002.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# calculated the correlation coefficient and linear regression model for southern hemisphere cloud cover versus
# latitude

# set variables (northern) for regression modelling
s_lati = southern_hemi_df['Lat']
s_wind = southern_hemi_df['Wind Speed']
s_xVals = s_lati
s_yVals = s_wind

# correlation and regression
corr = st.pearsonr(s_hum, s_wind)
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_xVals, s_yVals)
regressVals = s_xVals * slope + intercept
lineEQ = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

print(f"The correlation between wind speed and latitude is {round(corr[0],4)}.")
print(f"The r-squared value is: {round(rvalue**2, 4)}.")

plt.figure(figsize=(10, 6))
plt.scatter(s_xVals, s_yVals, s=30, color='tab:green', edgecolors='gray')
plt.plot(s_xVals, regressVals, 'k-', alpha=0.5)
plt.annotate(lineEQ, xy=(60, 10), fontsize=12, color='k')
plt.title('Latitude vs. Wind Speed (Southern Hemisphere)', fontsize=14, fontweight='bold')
plt.xlabel('Latitude', fontsize=12, fontweight='bold')
plt.ylabel('Wind Speed (mph)', fontsize=12, fontweight='bold')
plt.savefig("images/LATvWND_southern.png")
plt.show()
# Out:
# The correlation between wind speed and latitude is 0.0502.
# The r-squared value is: 0.1425.
